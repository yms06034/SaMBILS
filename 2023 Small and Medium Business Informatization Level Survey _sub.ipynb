# %%
def twentyfive_page_field(browser, 
    tfive1,tfive2,tfive3,tfive4,tfive5,tfive6,tfive7,tfive8,tfive9, tfive10,tfive11,
    tfive12,tfive13,tfive14,tfive15,tfive16,tfive17,tfive18, tfive19, tfive20, tfive21):
    count1 = 0
    count2 = 0
    count3 = 0
    count4 = 0
    count5 = 0
    count6 = 0
    count7 = 0
    count8 = 0
    count9 = 0
    count10 = 0
    count11 = 0
    count12 = 0
    count13 = 0
    count14 = 0
    count15 = 0
    count16 = 0
    count17 = 0
    count18 = 0
    count19 = 0
    count20 = 0
    count21 = 0
    
    
    if tfive1 == 1:
        find_id('objD4a_1_9', browser).click()
        count1 += 1
    elif tfive1 == 2:
        find_id('objD4a_1_1', browser).click()
        count1 += 1
    elif tfive1 == 3:
        find_id('objD4a_1_2', browser).click()
        count1 += 1
    elif tfive1 == 4:
        find_id('objD4a_1_3', browser).click()
        count1 += 1
    elif tfive1 == 5:
        find_id('objD4a_1_4', browser).click()
        count1 += 1
    elif tfive1 == 6:
        find_id('objD4a_1_5', browser).click()
        count1 += 1
    
    if tfive2 == 1:
        find_id('objD4a_2_9', browser).click()
        count2 += 1
    elif tfive2 == 2:
        find_id('objD4a_2_1', browser).click()
        count2 += 1
    elif tfive2 == 3:
        find_id('objD4a_2_2', browser).click()
        count2 += 1
    elif tfive2 == 4:
        find_id('objD4a_2_3', browser).click()
        count2 += 1
    elif tfive2 == 5:
        find_id('objD4a_2_4', browser).click()
        count2 += 1
    elif tfive2 == 6:
        find_id('objD4a_2_5', browser).click()
        count2 += 1
        
    if tfive3 == 1:
        find_id('objD4a_3_9', browser).click()
        count3 += 1
    elif tfive3 == 2:
        find_id('objD4a_3_1', browser).click()
        count3 += 1
    elif tfive3 == 3:
        find_id('objD4a_3_2', browser).click()
        count3 += 1
    elif tfive3 == 4:
        find_id('objD4a_3_3', browser).click()
        count3 += 1
    elif tfive3 == 5:
        find_id('objD4a_3_4', browser).click()
        count3 += 1
    elif tfive3 == 6:
        find_id('objD4a_3_5', browser).click()
        count3 += 1
        
    if tfive4 == 1:
        find_id('objD4a_4_9', browser).click()
        count4 += 1
    elif tfive4 == 2:
        find_id('objD4a_4_1', browser).click()
        count4 += 1
    elif tfive4 == 3:
        find_id('objD4a_4_2', browser).click()
        count4 += 1
    elif tfive4 == 4:
        find_id('objD4a_4_3', browser).click()
        count4 += 1
    elif tfive4 == 5:
        find_id('objD4a_4_4', browser).click()
        count4 += 1
    elif tfive4 == 6:
        find_id('objD4a_4_5', browser).click()
        count4 += 1
        
    if tfive5 == 1:
        find_id('objD4a_5_9', browser).click()
        count5 += 1
    elif tfive5 == 2:
        find_id('objD4a_5_1', browser).click()
        count5 += 1
    elif tfive5 == 3:
        find_id('objD4a_5_2', browser).click()
        count5 += 1
    elif tfive5 == 4:
        find_id('objD4a_5_3', browser).click()
        count5 += 1
    elif tfive5 == 5:
        find_id('objD4a_5_4', browser).click()
        count5 += 1
    elif tfive5 == 6:
        find_id('objD4a_5_5', browser).click()
        count5 += 1
        
    if tfive6== 1:
        find_id('objD4a_6_9', browser).click()
        count6 += 1
    elif tfive6 == 2:
        find_id('objD4a_6_1', browser).click()
        count6 += 1
    elif tfive6 == 3:
        find_id('objD4a_6_2', browser).click()
        count6 += 1
    elif tfive6 == 4:
        find_id('objD4a_6_3', browser).click()
        count6 += 1
    elif tfive6 == 5:
        find_id('objD4a_6_4', browser).click()
        count6 += 1
    elif tfive6 == 6:
        find_id('objD4a_6_5', browser).click()
        count6 += 1

    if tfive7== 1:
        find_id('objD4a_7_9', browser).click()
        count7 += 1
    elif tfive7 == 2:
        find_id('objD4a_7_1', browser).click()
        count7 += 1
    elif tfive7 == 3:
        find_id('objD4a_7_2', browser).click()
        count7 += 1
    elif tfive7 == 4:
        find_id('objD4a_7_3', browser).click()
        count7 += 1
    elif tfive7 == 5:
        find_id('objD4a_7_4', browser).click()
        count7 += 1
    elif tfive7 == 6:
        find_id('objD4a_7_5', browser).click()
        count7 += 1

    if tfive8 == 1:
        find_id('objD4a_8_9', browser).click()
        count8 += 1
    elif tfive8 == 2:
        find_id('objD4a_8_1', browser).click()
        count8 += 1
    elif tfive8 == 3:
        find_id('objD4a_8_2', browser).click()
        count8 += 1
    elif tfive8 == 4:
        find_id('objD4a_8_3', browser).click()
        count8 += 1
    elif tfive8 == 5:
        find_id('objD4a_8_4', browser).click()
        count8 += 1
    elif tfive8 == 6:
        find_id('objD4a_8_5', browser).click()
        count8 += 1

    if tfive9 == 1:
        find_id('objD4a_9_9', browser).click()
        count9 += 1
    elif tfive9 == 2:
        find_id('objD4a_9_1', browser).click()
        count9 += 1
    elif tfive9 == 3:
        find_id('objD4a_9_2', browser).click()
        count9 += 1
    elif tfive9 == 4:
        find_id('objD4a_9_3', browser).click()
        count9 += 1
    elif tfive9 == 5:
        find_id('objD4a_9_4', browser).click()
        count9 += 1
    elif tfive9 == 6:
        find_id('objD4a_9_5', browser).click()
        count9 += 1

    if tfive10 == 1:
        find_id('objD4a_10_9', browser).click()
        count10 += 1
    elif tfive10 == 2:
        find_id('objD4a_10_1', browser).click()
        count10 += 1
    elif tfive10 == 3:
        find_id('objD4a_10_2', browser).click()
        count10 += 1
    elif tfive10 == 4:
        find_id('objD4a_10_3', browser).click()
        count10 += 1
    elif tfive10 == 5:
        find_id('objD4a_10_4', browser).click()
        count10 += 1
    elif tfive10 == 6:
        find_id('objD4a_10_5', browser).click()
        count10 += 1

    if tfive11 == 1:
        find_id('objD4a_11_9', browser).click()
        count11 += 1
    elif tfive11 == 2:
        find_id('objD4a_11_1', browser).click()
        count11 += 1
    elif tfive11 == 3:
        find_id('objD4a_11_2', browser).click()
        count11 += 1
    elif tfive11 == 4:
        find_id('objD4a_11_3', browser).click()
        count11 += 1
    elif tfive11 == 5:
        find_id('objD4a_11_4', browser).click()
        count11 += 1
    elif tfive11 == 6:
        find_id('objD4a_11_5', browser).click()
        count11 += 1

    if tfive12 == 1:
        find_id('objD4a_12_9', browser).click()
        count12 += 1
    elif tfive12 == 2:
        find_id('objD4a_12_1', browser).click()
        count12 += 1
    elif tfive12 == 3:
        find_id('objD4a_12_2', browser).click()
        count12 += 1
    elif tfive12 == 4:
        find_id('objD4a_12_3', browser).click()
        count12 += 1
    elif tfive12 == 5:
        find_id('objD4a_12_4', browser).click()
        count12 += 1
    elif tfive12 == 6:
        find_id('objD4a_12_5', browser).click()
        count12 += 1
        
    if tfive13 == 1:
        find_id('objD4a_13_9', browser).click()
        count13 += 1
    elif tfive13 == 2:
        find_id('objD4a_13_1', browser).click()
        count13 += 1
    elif tfive13 == 3:
        find_id('objD4a_13_2', browser).click()
        count13 += 1
    elif tfive13 == 4:
        find_id('objD4a_13_3', browser).click()
        count13 += 1
    elif tfive13 == 5:
        find_id('objD4a_13_4', browser).click()
        count13 += 1
    elif tfive13 == 6:
        find_id('objD4a_13_5', browser).click()
        count13 += 1

    if tfive14 == 1:
        find_id('objD4a_14_9', browser).click()
        count14 += 1
    elif tfive14 == 2:
        find_id('objD4a_14_1', browser).click()
        count14 += 1
    elif tfive14 == 3:
        find_id('objD4a_14_2', browser).click()
        count14 += 1
    elif tfive14 == 4:
        find_id('objD4a_14_3', browser).click()
        count14 += 1
    elif tfive14 == 5:
        find_id('objD4a_14_4', browser).click()
        count14 += 1
    elif tfive14 == 6:
        find_id('objD4a_14_5', browser).click()
        count14 += 1

    if tfive15 == 1:
        find_id('objD4a_15_9', browser).click()
        count15 += 1
    elif tfive15 == 2:
        find_id('objD4a_15_1', browser).click()
        count15 += 1
    elif tfive15 == 3:
        find_id('objD4a_15_2', browser).click()
        count15 += 1
    elif tfive15 == 4:
        find_id('objD4a_15_3', browser).click()
        count15 += 1
    elif tfive15 == 5:
        find_id('objD4a_15_4', browser).click()
        count15 += 1
    elif tfive15 == 6:
        find_id('objD4a_15_5', browser).click()
        count15 += 1

    if tfive16 == 1:
        find_id('objD4a_16_9', browser).click()
        count16 += 1
    elif tfive16 == 2:
        find_id('objD4a_16_1', browser).click()
        count16 += 1
    elif tfive16 == 3:
        find_id('objD4a_16_2', browser).click()
        count16 += 1
    elif tfive16 == 4:
        find_id('objD4a_16_3', browser).click()
        count16 += 1
    elif tfive16 == 5:
        find_id('objD4a_16_4', browser).click()
        count16 += 1
    elif tfive16 == 6:
        find_id('objD4a_16_5', browser).click()
        count16 += 1

    if tfive17 == 1:
        find_id('objD4a_17_9', browser).click()
        count17 += 1
    elif tfive17 == 2:
        find_id('objD4a_17_1', browser).click()
        count17 += 1
    elif tfive17 == 3:
        find_id('objD4a_17_2', browser).click()
        count17 += 1
    elif tfive17 == 4:
        find_id('objD4a_17_3', browser).click()
        count17 += 1
    elif tfive17 == 5:
        find_id('objD4a_17_4', browser).click()
        count17 += 1
    elif tfive17 == 6:
        find_id('objD4a_17_5', browser).click()
        count17 += 1

    if tfive18 == 1:
        find_id('objD4a_18_9', browser).click()
        count18 += 1
    elif tfive18 == 2:
        find_id('objD4a_18_1', browser).click()
        count18 += 1
    elif tfive18 == 3:
        find_id('objD4a_18_2', browser).click()
        count18 += 1
    elif tfive18 == 4:
        find_id('objD4a_18_3', browser).click()
        count18 += 1
    elif tfive18 == 5:
        find_id('objD4a_18_4', browser).click()
        count18 += 1
    elif tfive18 == 6:
        find_id('objD4a_18_5', browser).click()
        count18 += 1

    if tfive19 == 1:
        find_id('objD4a_19_9', browser).click()
        count19 += 1
    elif tfive19 == 2:
        find_id('objD4a_19_1', browser).click()
        count19 += 1
    elif tfive19 == 3:
        find_id('objD4a_19_2', browser).click()
        count19 += 1
    elif tfive19 == 4:
        find_id('objD4a_19_3', browser).click()
        count19 += 1
    elif tfive19 == 5:
        find_id('objD4a_19_4', browser).click()
        count19 += 1
    elif tfive19 == 6:
        find_id('objD4a_19_5', browser).click()
        count19 += 1

    if tfive20 == 1:
        find_id('objD4a_20_9', browser).click()
        count20 += 1
    elif tfive20 == 2:
        find_id('objD4a_20_1', browser).click()
        count20 += 1
    elif tfive20 == 3:
        find_id('objD4a_20_2', browser).click()
        count20 += 1
    elif tfive20 == 4:
        find_id('objD4a_20_3', browser).click()
        count20 += 1
    elif tfive20 == 5:
        find_id('objD4a_20_4', browser).click()
        count20 += 1
    elif tfive20 == 6:
        find_id('objD4a_20_5', browser).click()
        count20 += 1

    if tfive21 == 1:
        find_id('objD4a_21_9', browser).click()
        count21 += 1
    elif tfive21 == 2:
        find_id('objD4a_21_1', browser).click()
        count21 += 1
    elif tfive21 == 3:
        find_id('objD4a_21_2', browser).click()
        count21 += 1
    elif tfive21 == 4:
        find_id('objD4a_21_3', browser).click()
        count21 += 1
    elif tfive21 == 5:
        find_id('objD4a_21_4', browser).click()
        count21 += 1
    elif tfive21 == 6:
        find_id('objD4a_21_5', browser).click()
        count21 += 1
        
    time.sleep(1)
    find_id('BtnNextPage', browser).click()
    
    try:
        time.sleep(1)
        find_name('jqi_state0_buttonsysLngFrmChk002', browser).click()
        time.sleep(1)
        find_id('BtnNextPage', browser).click()
    except:
        pass
    
    time.sleep(1)
